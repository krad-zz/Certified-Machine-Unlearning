# %%
import numpy as np
import scipy.linalg
import statsmodels.api as sm
from scipy.stats import gamma

def sample_b(p, C):
    # Step 1: Sample r ~ Gamma(p, scale=1/C)
    r = gamma.rvs(a=p, scale=1/C)

    # Step 2: Sample a unit vector u ~ Uniform(S^(p-1))
    u = np.random.randn(p)
    u /= np.linalg.norm(u)  # Normalize to unit sphere

    # Step 3: Scale the unit vector
    b = r * u
    return b

# Logistic Ridge Regression Functions
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def loss(beta, X, y, lambda_):
    n              = X.shape[0]
    logits         = X @ beta
    log_likelihood = -np.mean(y * logits - np.log(1 + np.exp(logits)))
    ridge_penalty  = 0.5 * lambda_ * np.sum(beta**2) / n
    return log_likelihood + ridge_penalty

def gradient(beta, X, y, lambda_):
    pr = sigmoid(X @ beta)
    return -X.T @ (y - pr) + lambda_ * beta

def hessian(beta, X, lambda_):
    pr = sigmoid(X @ beta)
    W = np.diag(pr * (1 - pr))
    return X.T @ W @ X + lambda_ * np.eye(X.shape[1])


def conjugate_gradient_logistic(X, y, beta, z_init, lambda_, tol=1e-8, max_iter=1000000):
    """
    Conjugate Gradient solver for logistic ridge regression Newton step:
    Solves H @ z = -grad without forming H or grad explicitly.

    Args:
        X        : (n x p) design matrix
        y        : (n,) binary labels
        beta     : (p,) current beta vector
        z_init   : (p,) initial guess for solution z
        lambda_  : regularization parameter
        tol      : tolerance for convergence
        max_iter : max number of CG iterations

    Returns:
        z : solution to H @ z = -grad
    """
    n, d = X.shape
    pr = sigmoid(X @ beta)

    # Hessian-vector product
    def Hv(v):
        Xv = X @ v
        W_Xv = (pr * (1 - pr)) * Xv
        return X.T @ W_Xv + lambda_ * v

    # Gradient vector
    grad = -X.T @ (y - pr) + lambda_ * beta

    # Conjugate gradient to solve H @ z = -grad
    z = z_init.copy()
    r = -grad - Hv(z)
    d_vec = r.copy()
    r_dot_old = np.dot(r, r)

    for cg_count in range(1, max_iter+1):
        Hd = Hv(d_vec)
        alpha = r_dot_old / np.dot(d_vec, Hd)
        z += alpha * d_vec
        r -= alpha * Hd
        r_dot_new = np.dot(r, r)
        if np.sqrt(r_dot_new) < tol:
            break
        beta_cg = r_dot_new / r_dot_old
        d_vec = r + beta_cg * d_vec
        r_dot_old = r_dot_new
    return z, cg_count


def newton_step(beta_init, X, y, lambda_, tol=1e-6, max_iter=100, cg=False, cg_tol=1e-16):
    beta = beta_init.copy()
    for step_count in range(1, max_iter + 1):
        if cg:
          z_init    = 0.00 * np.random.randn(len(beta))
          z, cg_count         = conjugate_gradient_logistic(X, y, beta, z_init, lambda_, tol=cg_tol) # computes -hess^{-1} * grad
          #hess      = hessian(beta, X, lambda_)
          #grad      = gradient(beta, X, y, lambda_)
          #z_alt     = -np.linalg.solve(hess, grad)
          #print(f"sum |z - z_alt|/sum|z_alt| = {np.sum(np.abs(z - z_alt))/np.sum(np.abs(z_alt)):.10f}")
        else:
          grad = gradient(beta, X, y, lambda_)
          hess = hessian(beta, X, lambda_)
          z    = -np.linalg.solve(hess, grad)
        beta += z
        if np.linalg.norm(z) < tol:
            return beta, step_count
    return beta, max_iter

# Main code
np.random.seed(24)
logp_     = np.arange(start=1, stop=7, step=1)
plogstep  = 10 ** 0.2
p_        = np.floor(360 * plogstep ** logp_).astype(int)
delta     = 1  # n/p
lambda_   = 0.1  # Ridge regularization
nn        = 100
e         = 0.1
cg_tol    = 1e-18
newton_tol= 1e-3
cg        = True
cg_count  = 0
#  Initialization
meanErr_tilde     = np.zeros(len(p_))
sdErr_tilde       = np.zeros(len(p_))
meanErr_tilde_2   = np.zeros(len(p_))
sdErr_tilde_2     = np.zeros(len(p_))
meanErr_hat       = np.zeros(len(p_))
sdErr_hat         = np.zeros(len(p_))

loss_hat          = np.zeros((nn, len(p_))) # loss of the exact unlearned model, tested on the unlearned datapoint
loss_tilde        = np.zeros((nn, len(p_))) # loss of the one Newton step unlearned model, tested on the unlearned datapoint
loss_tilde_2      = np.zeros((nn, len(p_))) # loss of the two Newton step unlearned model, tested on the unlearned datapoint
loss_new_hat      = np.zeros((nn, len(p_))) # loss of the exact unlearned model, tested on the unlearned datapoint
loss_new_tilde    = np.zeros((nn, len(p_))) # loss of the one Newton step unlearned model, tested on  many new datapoints
loss_new_tilde_2  = np.zeros((nn, len(p_))) # loss of the two Newton step unlearned model, tested on  many new datapoints


for i, p in enumerate(p_):
    beta_star = np.random.normal(0, 1, p)
    n         = int(p * delta)  # Define `n` based on `delta`
    X         = np.random.normal(0, 1 / np.sqrt(n), (n, p))
    logits    = X @ beta_star
    prob      = sigmoid(logits)
    y         = np.random.binomial(1, prob)

    beta_init            = np.random.normal(0, 1, p) * 0.001
    beta_hat, steps_used = newton_step(beta_init, X, y, lambda_, tol=newton_tol, cg=cg, cg_tol=cg_tol)

    if i==0:
      p_hat     = sigmoid(X @ beta_hat)
      W         = np.diag(p_hat * (1 - p_hat))
      # Use pseudo-inverse to prevent singular matrix error
      hess_inv  = scipy.linalg.pinv(hessian(beta_hat, X, lambda_))
      H         = X @ hess_inv @ X.T @ W
      tr_H      = np.trace(H) / p

    err_tilde   = np.zeros(nn)
    err_tilde_2 = np.zeros(nn)
    err_hat     = np.zeros(nn)

    for j in range(nn):
        X_j_out = np.delete(X, j, axis=0)
        y_j_out = np.delete(y, j)

        beta_init              = 0.00 * np.random.randn(p)
        beta_hat_j, steps_used = newton_step(beta_init, X_j_out, y_j_out, lambda_, tol=newton_tol, cg=cg, cg_tol=cg_tol)
        err_hat[j]             = np.linalg.norm(beta_hat - beta_hat_j)

        #  beta tilde calculation
        if cg:
          z_init                 = 0.00 * np.random.randn(p)
          z, cg_count            = conjugate_gradient_logistic(X_j_out, y_j_out, beta_hat, z_init, lambda_, tol=cg_tol) # computes -hess^{-1} * grad
          #hess_j_out_hat         = hessian(beta_hat, X_j_out, lambda_)
          #grad_j_out_hat         = gradient(beta_hat, X_j_out, y_j_out, lambda_)
          #z                      = -np.linalg.solve(hess_j_out_hat, grad_j_out_hat)
          #print(f"sum |z - z_alt|/sum|z_alt| = {np.sum(np.abs(z - z_alt))/np.sum(np.abs(z_alt)):.10f}")
        else:
          hess_j_out_hat         = hessian(beta_hat, X_j_out, lambda_)
          grad_j_out_hat         = gradient(beta_hat, X_j_out, y_j_out, lambda_)
          z                      = -np.linalg.solve(hess_j_out_hat, grad_j_out_hat)

        beta_tld_j             = beta_hat + z
        err_tilde[j]           = np.linalg.norm(beta_tld_j - beta_hat_j)

        #  beta tilde 2 calculation
        if cg:
          z_init                 = 0.00 * np.random.randn(p)
          z, cg_count            = conjugate_gradient_logistic(X_j_out, y_j_out, beta_tld_j, z_init, lambda_, tol=cg_tol) # computes -hess^{-1} * grad
          #hess_j_out_tilde       = hessian(beta_tld_j, X_j_out, lambda_)
          #grad_j_out_tilde       = gradient(beta_tld_j, X_j_out, y_j_out, lambda_)
          #z                      = -np.linalg.solve(hess_j_out_tilde, grad_j_out_tilde)
          #print(f"sum |z - z_alt|/sum|z_alt| = {np.sum(np.abs(z - z_alt))/np.sum(np.abs(z_alt)):.6f}")
        else:
          hess_j_out_tilde       = hessian(beta_tld_j, X_j_out, lambda_)
          grad_j_out_tilde       = gradient(beta_tld_j, X_j_out, y_j_out, lambda_)
          z                      = - np.linalg.solve(hess_j_out_tilde, grad_j_out_tilde)
        beta_tld_j_2           = beta_tld_j + z
        err_tilde_2[j]         = np.linalg.norm(beta_tld_j_2 - beta_hat_j)

    print(f"---------------- n = {n}, p = {p},  df/p = {tr_H:.2f}, lambda = {lambda_}, cg_count = {cg_count}, newton steps: {steps_used} ----------------")
    meanErr_tilde[i]   = np.mean(err_tilde)
    sdErr_tilde[i]     = np.std(err_tilde)
    meanErr_tilde_2[i] = np.mean(err_tilde_2)
    sdErr_tilde_2[i]   = np.std(err_tilde_2)
    meanErr_hat[i]     = np.mean(err_hat)
    sdErr_hat[i]       = np.std(err_hat)
    # Linear regression log(error) vs log(m)
    if i > 1:
      log_p = np.log(p_[:i+1])
      X_reg = sm.add_constant(log_p)
      def fit_model(errors):
        return sm.OLS(np.log(errors), X_reg).fit()
      models = {
          "tilde": fit_model(meanErr_tilde[:i+1]),
          "tilde_2": fit_model(meanErr_tilde_2[:i+1]),
          "hat": fit_model(meanErr_hat[:i+1]),
      }
      results = {
          name: {
              "slope": model.params[1],
              "conf_int": model.conf_int()[1],
              "R2": model.rsquared,
              }
              for name, model in models.items()
      }
      print(f"   "
        f"1 step: slope={results['tilde']['slope']:.2f}, "
        f"CI=({results['tilde']['conf_int'][0]:6.2f},{results['tilde']['conf_int'][1]:6.2f}), R²={results['tilde']['R2']:.2f} | "
        f"| 2 step: slope={results['tilde_2']['slope']:.2f}, "
        f"CI=({results['tilde_2']['conf_int'][0]:6.2f},{results['tilde_2']['conf_int'][1]:6.2f}), R²={results['tilde_2']['R2']:.2f} | "
        f"| exact: slope={results['hat']['slope']:.2f}, "
        f"CI=({results['hat']['conf_int'][0]:6.2f},{results['hat']['conf_int'][1]:6.2f}), R²={results['hat']['R2']:.2f} |")
      print("--------------------------------------------------------------------------------------------------------------------------------")

    rmax1             = np.max(err_tilde)    *  np.sqrt(np.log(n) / np.log(nn))
    rmax2             = np.max(err_tilde_2)  *  np.sqrt(np.log(n) / np.log(nn))
    n_new             = 1
    #print(f"---------------- np.max(err_tilde) = {np.max(err_tilde):.7f}, np.max(err_tilde_2)= {np.max(err_tilde_2):.7f} ----------------")
    #print(f"---------------- rmax1 = {rmax1:.7f}, rmax2 = {rmax2:.7f}---------------- ")

    for j in range(nn):
        X_j_out                = np.delete(X, j, axis=0)
        y_j_out                = np.delete(y, j)

        X_new                  = np.random.normal(0, 1 / np.sqrt(n), (n_new, p))
        logits_new             = X_new @ beta_star
        prob_new               = sigmoid(logits_new)
        y_new                  = np.random.binomial(1, prob_new)
        # exact unlearned model
        beta_init              = 0.00 * np.random.randn(p)
        beta_hat_j, steps_used = newton_step(beta_init, X_j_out, y_j_out, lambda_, tol=newton_tol, cg=cg, cg_tol=cg_tol)
        loss_hat[j, i]         = loss(beta_hat_j, X[j, :], y[j], lambda_=0)
        loss_new_hat[j, i]     = loss(beta_hat_j, X_new, y_new, lambda_=0)

        #  one Newton step: beta tilde calculation
        b1                     = sample_b(p, e/rmax1) * 1
        #print(f" Q1: {np.percentile(b1, 25):.5f}, Median: {np.median(b1):.5f}, Q3: {np.percentile(b1, 75):.5f}")
        #  beta tilde calculation
        if cg:
          z_init                 = 0.00 * np.random.randn(p)
          z, cg_count            = conjugate_gradient_logistic(X_j_out, y_j_out, beta_hat, z_init, lambda_, tol=cg_tol) # computes -hess^{-1} * grad
        else:
          hess_j_out_hat         = hessian(beta_hat, X_j_out, lambda_)
          grad_j_out_hat         = gradient(beta_hat, X_j_out, y_j_out, lambda_)
          z                      = -np.linalg.solve(hess_j_out_hat, grad_j_out_hat)
        beta_tld_j             = beta_hat + z
        loss_tilde[j, i]       = loss(b1 + beta_tld_j, X[j, :], y[j], lambda_=0)
        loss_new_tilde[j, i]   = loss(b1 + beta_tld_j, X_new, y_new, lambda_=0)

        #  two Newton step: beta tilde 2 calculation
        b2                     = sample_b(p, e/rmax2) * 1
        #print(f" Q1: {np.percentile(b2, 25):.5f}, Median: {np.median(b2):.5f}, Q3: {np.percentile(b2, 75):.5f}")
        if cg:
          z_init                 = 0.00 * np.random.randn(p)
          z, cg_count            = conjugate_gradient_logistic(X_j_out, y_j_out, beta_tld_j, z_init, lambda_, tol=cg_tol) # computes -hess^{-1} * grad
        else:
          hess_j_out_tilde       = hessian(beta_tld_j, X_j_out, lambda_)
          grad_j_out_tilde       = gradient(beta_tld_j, X_j_out, y_j_out, lambda_)
          z                      = - np.linalg.solve(hess_j_out_tilde, grad_j_out_tilde)
        beta_tld_j_2           = beta_tld_j + z
        loss_tilde_2[j, i]     = loss(b2 + beta_tld_j_2, X[j, :], y[j], lambda_=0)
        loss_new_tilde_2[j, i] = loss(b2 + beta_tld_j_2, X_new, y_new, lambda_=0)


def five_number_summary(x):
  print(f"Min: {np.min(x):.5f}, Q1: {np.percentile(x, 25):.5f}, Median: {np.median(x):.5f}, Q3: {np.percentile(x, 75):.5f}, Max: {np.max(x):.5f}")
five_number_summary(b1)
five_number_summary(b2)
# Out:
# ---------------- n = 570, p = 570,  df/p = 0.44, lambda = 0.1, cg_count = 44, newton steps: 5 ----------------
# ---------------- n = 904, p = 904,  df/p = 0.44, lambda = 0.1, cg_count = 47, newton steps: 5 ----------------
# ---------------- n = 1433, p = 1433,  df/p = 0.44, lambda = 0.1, cg_count = 46, newton steps: 5 ----------------
#    1 step: slope=-0.80, CI=( -1.32, -0.27), R²=1.00 | | 2 step: slope=-1.84, CI=( -4.41,  0.73), R²=0.99 | | exact: slope=-0.19, CI=( -0.77,  0.38), R²=0.95 |
# --------------------------------------------------------------------------------------------------------------------------------
# ---------------- n = 2271, p = 2271,  df/p = 0.44, lambda = 0.1, cg_count = 43, newton steps: 5 ----------------
#    1 step: slope=-0.69, CI=( -0.96, -0.41), R²=0.98 | | 2 step: slope=-1.84, CI=( -2.23, -1.45), R²=1.00 | | exact: slope=-0.11, CI=( -0.34,  0.13), R²=0.66 |
# --------------------------------------------------------------------------------------------------------------------------------
# ---------------- n = 3600, p = 3600,  df/p = 0.44, lambda = 0.1, cg_count = 48, newton steps: 5 ----------------
#    1 step: slope=-0.70, CI=( -0.81, -0.58), R²=0.99 | | 2 step: slope=-1.96, CI=( -2.23, -1.68), R²=0.99 | | exact: slope=-0.09, CI=( -0.20,  0.01), R²=0.73 |
# --------------------------------------------------------------------------------------------------------------------------------
# ---------------- n = 5705, p = 5705,  df/p = 0.44, lambda = 0.1, cg_count = 47, newton steps: 5 ----------------
#    1 step: slope=-0.56, CI=( -0.79, -0.34), R²=0.92 | | 2 step: slope=-1.66, CI=( -2.16, -1.17), R²=0.96 | | exact: slope=-0.03, CI=( -0.15,  0.09), R²=0.11 |
# --------------------------------------------------------------------------------------------------------------------------------
# Min: -53.13145, Q1: -10.27133, Median: -0.01345, Q3: 10.63292, Max: 60.93810
# Min: -0.00667, Q1: -0.00121, Median: 0.00002, Q3: 0.00121, Max: 0.00701

# %%
print(p_)
# Out:
# [904]

# %%
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

def add_regression_on_means(ax, p_vals, diff_matrix):
    # Compute log-log regression on column means only
    means = np.mean(diff_matrix, axis=0)
    mask = (means > 0) & (p_vals > 0)
    X_log = np.log(p_vals[mask])
    y_log = np.log(means[mask])
    X_design = sm.add_constant(X_log)

    model = sm.OLS(y_log, X_design).fit()
    slope = model.params[1]
    ci_low, ci_high = model.conf_int()[1]
    R2 = model.rsquared

    p_plot = np.linspace(p_vals.min(), p_vals.max(), 200)
    y_pred = np.exp(model.predict(sm.add_constant(np.log(p_plot))))

    ax.plot(p_plot, y_pred, color='red', linestyle='--',
            label=f'slope: {slope:.2f}, CI: [{ci_low:.2f}, {ci_high:.2f}], R²: {R2:.2f}')
    ax.legend()

# --- Titles ---
titles = [
    "In-sample Loss (Exact)",
    "In-sample Diff (1-step vs Exact)",
    "In-sample Diff (2-step vs Exact)",
    "Out-of-sample Loss (Exact)",
    "Out-of-sample Diff (1-step vs Exact)",
    "Out-of-sample Diff (2-step vs Exact)"
]

# --- Begin Plotting ---
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

# Compute mean ± SD
def compute_mean_sd(matrix):
    means = np.mean(matrix, axis=0)
    sds   = np.std(matrix, axis=0)
    return means, sds

in_sample_diff1 = np.abs(loss_tilde - loss_hat)
in_sample_diff2 = np.abs(loss_tilde_2 - loss_hat)
out_sample_diff1 = np.abs(loss_new_tilde - loss_new_hat)
out_sample_diff2 = np.abs(loss_new_tilde_2 - loss_new_hat)

# 1. In-sample raw loss
means, sds = compute_mean_sd(loss_hat)
axes[0].errorbar(p_, means, yerr=sds, fmt='o', capsize=4)
axes[0].set_title(titles[0])
axes[0].set_xlabel(r'$p$')
axes[0].set_ylabel(r'Loss')

# 2. In-sample diff (1 step)
means, sds = compute_mean_sd(in_sample_diff1)
axes[1].errorbar(p_, means, yerr=sds, fmt='o', capsize=4)
axes[1].set_title(titles[1])
axes[1].set_xlabel(r'$p$')
axes[1].set_ylabel(r'Difference')
add_regression_on_means(axes[1], p_, in_sample_diff1)

# 3. In-sample diff (2 step)
means, sds = compute_mean_sd(in_sample_diff2)
axes[2].errorbar(p_, means, yerr=sds, fmt='o', capsize=4)
axes[2].set_title(titles[2])
axes[2].set_xlabel(r'$p$')
axes[2].set_ylabel(r'Difference')
add_regression_on_means(axes[2], p_, in_sample_diff2)

# 4. Out-of-sample raw loss
means, sds = compute_mean_sd(loss_new_hat)
axes[3].errorbar(p_, means, yerr=sds, fmt='o', capsize=4)
axes[3].set_title(titles[3])
axes[3].set_xlabel(r'$p$')
axes[3].set_ylabel(r'Loss')

# 5. Out-of-sample diff (1 step)
means, sds = compute_mean_sd(out_sample_diff1)
axes[4].errorbar(p_, means, yerr=sds, fmt='o', capsize=4)
axes[4].set_title(titles[4])
axes[4].set_xlabel(r'$p$')
axes[4].set_ylabel(r'Difference')
add_regression_on_means(axes[4], p_, out_sample_diff1)

# 6. Out-of-sample diff (2 step)
means, sds = compute_mean_sd(out_sample_diff2)
axes[5].errorbar(p_, means, yerr=sds, fmt='o', capsize=4)
axes[5].set_title(titles[5])
axes[5].set_xlabel(r'$p$')
axes[5].set_ylabel(r'Difference')
add_regression_on_means(axes[5], p_, out_sample_diff2)

# Apply log scales and grid to all plots
for ax in axes:
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.grid(True, which='both', linestyle='--', linewidth=0.5)
fig.suptitle(rf'Certified data removal by adding perturbations: n/p = {n/p:.1f}, df/p = {tr_H:.2f}, $\lambda$ = {lambda_}', fontsize=16, y=1.02)

plt.tight_layout()
plt.show()

# %%
print(delta*p_)
# Out:
# [904]

# %%
import numpy as np
from scipy.stats import gamma

def sample_b(p, C):
    # Step 1: Sample r ~ Gamma(p, scale=1/C)
    r = gamma.rvs(a=p, scale=1/C)

    # Step 2: Sample a unit vector u ~ Uniform(S^(p-1))
    u = np.random.randn(p)
    u /= np.linalg.norm(u)  # Normalize to unit sphere

    # Step 3: Scale the unit vector
    b = r * u
    return b

# Example usage
p = 1000   # Dimension
C = 0.1 # Parameter
sample = sample_b(p, C)
print(sample)
print(np.linalg.norm(sample))

# %%
# Re-import necessary libraries
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import pandas as pd

# Ensure p_, meanErr_*, and sdErr_* are all defined by this point

# Construct summary DataFrame
error_table = pd.DataFrame({
    'p': p_,
    'Mean Error Tilde': meanErr_tilde,
    'SD Tilde': sdErr_tilde,
    'Mean Error Tilde 2': meanErr_tilde_2,
    'SD Tilde 2': sdErr_tilde_2,
    'Mean Error Hat': meanErr_hat,
    'SD Hat': sdErr_hat
})

# Print the table in a readable format
print("\nError Summary Table:")
print(error_table.to_string(index=False))

# Log-transform mean errors and p values
log_p = np.log(p_)
log_meanErr_tilde   = np.log(meanErr_tilde)
log_meanErr_tilde_2 = np.log(meanErr_tilde_2)
log_meanErr_hat     = np.log(meanErr_hat)

# Prepare regression design matrix
X_reg = sm.add_constant(log_p)

# Weighted linear regressions
model_tilde    = sm.WLS(log_meanErr_tilde,   X_reg, weights=1 / sdErr_tilde).fit()
model_tilde_2  = sm.WLS(log_meanErr_tilde_2, X_reg, weights=1 / sdErr_tilde_2).fit()
model_hat      = sm.WLS(log_meanErr_hat,     X_reg, weights=1 / sdErr_hat).fit()

# Extract regression results
def extract_model_info(model):
    slope     = model.params[1]
    conf_int  = model.conf_int()[1]
    r_squared = model.rsquared
    return slope, conf_int, r_squared

slope_tilde,   conf_int_tilde,   R2_tilde   = extract_model_info(model_tilde)
slope_tilde_2, conf_int_tilde_2, R2_tilde_2 = extract_model_info(model_tilde_2)
slope_hat,     conf_int_hat,     R2_hat     = extract_model_info(model_hat)

# Print regression summaries
print("\nRegression Results (log error vs. log p):")
print(f"Tilde     Slope: {slope_tilde:.3f},  CI: ({conf_int_tilde[0]:.3f}, {conf_int_tilde[1]:.3f}),  R²: {R2_tilde:.3f}")
print(f"Tilde 2   Slope: {slope_tilde_2:.3f},  CI: ({conf_int_tilde_2[0]:.3f}, {conf_int_tilde_2[1]:.3f}),  R²: {R2_tilde_2:.3f}")
print(f"Hat       Slope: {slope_hat:.3f},  CI: ({conf_int_hat[0]:.3f}, {conf_int_hat[1]:.3f}),  R²: {R2_hat:.3f}")

# Optionally, predictions for plotting
log_error_pred_tilde    = model_tilde.predict(X_reg)
log_error_pred_tilde_2  = model_tilde_2.predict(X_reg)
log_error_pred_hat      = model_hat.predict(X_reg)


# Create a 1x3 panel plot with true log-log scale and error bars
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Titles including parameters
title_text = f"n/p={delta},  df/p={tr_H:.2f}, λ={lambda_}"

# --- Plot 1: Tilde (1-step approximation error)
axes[0].errorbar(p_, meanErr_tilde, yerr=sdErr_tilde, fmt='o',
                 color='blue', alpha=0.9, label=r'$\|\tilde{\beta}^{(1)}_{/ \mathcal{M}} - \hat{\beta}_{/ \mathcal{M}}\|_2$')
axes[0].plot(p_, np.exp(log_error_pred_tilde),
             label=f'slope: {slope_tilde:.2f}, CI: [{conf_int_tilde[0]:.2f}, {conf_int_tilde[1]:.2f}], R²: {R2_tilde:.2f}',
             color='blue', linestyle='--')
axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlabel(r'$p$')
axes[0].set_ylabel(r'$\|\cdot\|_2$')
axes[0].set_title(r'1-step leave-$\mathcal{M}$-out error' )
axes[0].legend()
axes[0].grid(True, which='both', linestyle='--', linewidth=0.5)

# --- Plot 2: Tilde 2 (2-step approximation error)
axes[1].errorbar(p_, meanErr_tilde_2, yerr=sdErr_tilde_2, fmt='o',
                 color='purple', alpha=0.9, label=r'$\|\tilde{\beta}^{(2)}_{/ \mathcal{M}} - \hat{\beta}_{/ \mathcal{M}}\|_2$')
axes[1].plot(p_, np.exp(log_error_pred_tilde_2),
             label=f'slope: {slope_tilde_2:.2f}, CI: [{conf_int_tilde_2[0]:.2f}, {conf_int_tilde_2[1]:.2f}], R²: {R2_tilde_2:.2f}',
             color='purple', linestyle='--')
axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlabel(r'$p$')
axes[1].set_ylabel(r'$\|\cdot\|_2$')
axes[1].set_title(r'2-step leave-$\mathcal{M}$-out error' )
axes[1].legend()
axes[1].grid(True, which='both', linestyle='--', linewidth=0.5)

# --- Plot 3: Hat (true leave-M-out perturbation)
axes[2].errorbar(p_, meanErr_hat, yerr=sdErr_hat, fmt='o',
                 color='green', alpha=0.9, label=r'$\|\hat{\beta}_{/ \mathcal{M}} - \hat{\beta}\|_2$')
axes[2].plot(p_, np.exp(log_error_pred_hat),
             label=f'slope: {slope_hat:.2f}, CI: [{conf_int_hat[0]:.2f}, {conf_int_hat[1]:.2f}], R²: {R2_hat:.2f}',
             color='green', linestyle='--')
axes[2].set_xscale('log')
axes[2].set_yscale('log')
axes[2].set_xlabel(r'$p$')
axes[2].set_ylabel(r'$\|\cdot\|_2$')
axes[2].set_title(r'exact leave-$\mathcal{M}$-out perturbation' )
axes[2].legend()
axes[2].grid(True, which='both', linestyle='--', linewidth=0.5)

fig.suptitle(rf'n/p = {n/p:.1f}, df/p = {tr_H:.2f}, $\lambda$ = {lambda_}', fontsize=16, y=1.02)

plt.tight_layout()
plt.show()
# Out:
# Error Summary Table:
#    p  Mean Error Tilde  SD Tilde  Mean Error Tilde 2   SD Tilde 2  Mean Error Hat   SD Hat
#  570          0.010417  0.009684        4.819938e-06 7.905090e-06        1.535918 0.788736
#  904          0.006983  0.008589        2.422948e-06 7.965245e-06        1.354670 0.774322
# 1433          0.005002  0.005514        8.828388e-07 2.151038e-06        1.284206 0.736865
# 2271          0.004036  0.004053        4.008900e-07 7.748237e-07        1.327362 0.703412
# 3600          0.002755  0.002357        1.305908e-07 2.053766e-07        1.255337 0.603668
# 5705          0.003096  0.003150        1.526001e-07 3.062828e-07        1.450698 0.799749
#
# Regression Results (log error vs. log p):
# Tilde     Slope: -0.531,  CI: (-0.814, -0.247),  R²: 0.871
# Tilde 2   Slope: -1.294,  CI: (-2.445, -0.143),  R²: 0.709
# Hat       Slope: -0.033,  CI: (-0.150, 0.083),  R²: 0.135

# %%
import numpy as np
import scipy.linalg
from scipy.stats import gamma



# --- Configuration ---
np.random.seed(42)
p = 500
delta = 0.5
lambda_ = 1
cg = False
cg_tol = 1e-18
newton_tol = 1e-3
e = 0.1

n = int(p * delta)
beta_star = np.random.normal(0, 1, p) * 2
X = np.random.normal(0, 1 / np.sqrt(n), (n, p))
y = np.random.binomial(1, sigmoid(X @ beta_star))

# --- Fit full model ---
beta_init = np.zeros(p)
beta_hat, _ = newton_step(beta_init, X, y, lambda_, tol=newton_tol, cg=cg, cg_tol=cg_tol)

# --- Precompute for tilde ---
p_hat = sigmoid(X @ beta_hat)
W = np.diag(p_hat * (1 - p_hat))
hess_inv = scipy.linalg.pinv(hessian(beta_hat, X, lambda_))
H = X @ hess_inv @ X.T @ W
tr_H = np.trace(H) / p

print(f"--- Fitted full model ---\nDegrees of freedom (df) ≈ trace(H)/p = {tr_H:.4f} (normalized), p = {p}, n = {n}\n")

# --- Leave-One-Out over all i in [0, n) ---
errors_hat = np.zeros(n)
errors_tilde = np.zeros(n)
errors_tilde_2 = np.zeros(n)
loss_hat = np.zeros(n)
loss_tilde = np.zeros(n)
loss_tilde_2 = np.zeros(n)

for i in range(n):
    X_i_out = np.delete(X, i, axis=0)
    y_i_out = np.delete(y, i)

    # Full re-fit on leave-one-out
    beta_hat_i, _ = newton_step(np.zeros(p), X_i_out, y_i_out, lambda_, tol=newton_tol, cg=cg, cg_tol=cg_tol)
    errors_hat[i] = np.linalg.norm(beta_hat - beta_hat_i)

    # One Newton step
    z1, _ = conjugate_gradient_logistic(X_i_out, y_i_out, beta_hat, np.zeros(p), lambda_, tol=cg_tol)
    beta_tilde = beta_hat + z1
    errors_tilde[i] = np.linalg.norm(beta_tilde - beta_hat_i)

    # Two Newton steps
    z2, _ = conjugate_gradient_logistic(X_i_out, y_i_out, beta_tilde, np.zeros(p), lambda_, tol=cg_tol)
    beta_tilde_2 = beta_tilde + z2
    errors_tilde_2[i] = np.linalg.norm(beta_tilde_2 - beta_hat_i)

for i in range(n):
    X_i_out = np.delete(X, i, axis=0)
    y_i_out = np.delete(y, i)

    # Full re-fit on leave-one-out
    beta_hat_i, _ = newton_step(np.zeros(p), X_i_out, y_i_out, lambda_, tol=newton_tol, cg=cg, cg_tol=cg_tol)
    loss_hat[i] = loss(beta_hat_i, X[i:i+1], y[i:i+1], lambda_=0)

    # One Newton step
    z1, _ = conjugate_gradient_logistic(X_i_out, y_i_out, beta_hat, np.zeros(p), lambda_, tol=cg_tol)
    beta_tilde = beta_hat + z1
    b1 = sample_b(p, e / errors_tilde.max())
    loss_tilde[i] = loss(beta_tilde + b1, X[i:i+1], y[i:i+1], lambda_=0)

    # Two Newton steps
    z2, _ = conjugate_gradient_logistic(X_i_out, y_i_out, beta_tilde, np.zeros(p), lambda_, tol=cg_tol)
    beta_tilde_2 = beta_tilde + z2
    b2 = sample_b(p, e / errors_tilde_2.max())
    loss_tilde_2[i] = loss(beta_tilde_2 + b2, X[i:i+1], y[i:i+1], lambda_=0)
    print(f"[Loss Loop]  i = {i+1}/{n} | loss_hat = {loss_hat[i]:.5f}, loss_1step = {loss_tilde[i]:.5f}, loss_2step = {loss_tilde_2[i]:.5f}")





def five_number_summary(x, name=""):
    print(f"{name} | Min: {np.min(x):.5f}, Q1: {np.percentile(x, 25):.5f}, Median: {np.median(x):.5f}, Q3: {np.percentile(x, 75):.5f}, Max: {np.max(x):.5f}")

print(f"\n--- Summary for p = {p}, n = {n}, df/p = {tr_H:.2f} ---")
five_number_summary(errors_hat, "Error (Exact LOO)")
five_number_summary(errors_tilde, "Error (1-Step)")
five_number_summary(errors_tilde_2, "Error (2-Step)")
five_number_summary(loss_hat, "Loss (Exact)")
five_number_summary(loss_tilde, "Loss (1-Step)")
five_number_summary(loss_tilde_2, "Loss (2-Step)")
# Out:
# --- Fitted full model ---
# Degrees of freedom (df) ≈ trace(H)/p = 0.1346 (normalized), p = 500, n = 250
#
# [Loss Loop]  i = 1/250 | loss_hat = 0.51942, loss_1step = 0.45516, loss_2step = 0.51941
# [Loss Loop]  i = 2/250 | loss_hat = 0.66708, loss_1step = 0.49393, loss_2step = 0.66709
# [Loss Loop]  i = 3/250 | loss_hat = 0.62543, loss_1step = 0.55024, loss_2step = 0.62542
# [Loss Loop]  i = 4/250 | loss_hat = 0.77975, loss_1step = 0.39581, loss_2step = 0.77976
# [Loss Loop]  i = 5/250 | loss_hat = 0.83177, loss_1step = 0.49164, loss_2step = 0.83176
# [Loss Loop]  i = 6/250 | loss_hat = 1.13097, loss_1step = 1.38486, loss_2step = 1.13097
# [Loss Loop]  i = 7/250 | loss_hat = 0.63395, loss_1step = 0.76926, loss_2step = 0.63394
# [Loss Loop]  i = 8/250 | loss_hat = 0.39205, loss_1step = 0.42928, loss_2step = 0.39206
# [Loss Loop]  i = 9/250 | loss_hat = 0.78721, loss_1step = 1.00368, loss_2step = 0.78721
# [Loss Loop]  i = 10/250 | loss_hat = 0.37392, loss_1step = 0.51851, loss_2step = 0.37392
# [Loss Loop]  i = 11/250 | loss_hat = 0.82371, loss_1step = 1.22762, loss_2step = 0.82370
# [Loss Loop]  i = 12/250 | loss_hat = 0.60387, loss_1step = 0.37901, loss_2step = 0.60387
# [Loss Loop]  i = 13/250 | loss_hat = 0.60131, loss_1step = 0.40904, loss_2step = 0.60129
# [Loss Loop]  i = 14/250 | loss_hat = 0.67718, loss_1step = 0.46631, loss_2step = 0.67719
# [Loss Loop]  i = 15/250 | loss_hat = 0.64666, loss_1step = 0.51066, loss_2step = 0.64666
# [Loss Loop]  i = 16/250 | loss_hat = 0.65739, loss_1step = 0.77991, loss_2step = 0.65739
# [Loss Loop]  i = 17/250 | loss_hat = 0.35411, loss_1step = 0.29381, loss_2step = 0.35410
# [Loss Loop]  i = 18/250 | loss_hat = 0.49165, loss_1step = 0.50117, loss_2step = 0.49165
# [Loss Loop]  i = 19/250 | loss_hat = 0.50618, loss_1step = 0.29783, loss_2step = 0.50619
# [Loss Loop]  i = 20/250 | loss_hat = 0.64867, loss_1step = 0.91005, loss_2step = 0.64866
# [Loss Loop]  i = 21/250 | loss_hat = 0.57126, loss_1step = 0.35694, loss_2step = 0.57128
# [Loss Loop]  i = 22/250 | loss_hat = 1.37385, loss_1step = 1.67867, loss_2step = 1.37386
# [Loss Loop]  i = 23/250 | loss_hat = 0.43838, loss_1step = 0.95581, loss_2step = 0.43839
# [Loss Loop]  i = 24/250 | loss_hat = 0.30390, loss_1step = 0.22073, loss_2step = 0.30391
# [Loss Loop]  i = 25/250 | loss_hat = 0.57999, loss_1step = 0.60922, loss_2step = 0.58000
# [Loss Loop]  i = 26/250 | loss_hat = 0.69113, loss_1step = 0.76229, loss_2step = 0.69112
# [Loss Loop]  i = 27/250 | loss_hat = 0.55992, loss_1step = 0.41014, loss_2step = 0.55994
# [Loss Loop]  i = 28/250 | loss_hat = 0.82553, loss_1step = 0.77373, loss_2step = 0.82553
# [Loss Loop]  i = 29/250 | loss_hat = 1.22259, loss_1step = 0.97715, loss_2step = 1.22260
# [Loss Loop]  i = 30/250 | loss_hat = 0.68072, loss_1step = 0.44112, loss_2step = 0.68072
# [Loss Loop]  i = 31/250 | loss_hat = 0.33833, loss_1step = 0.31920, loss_2step = 0.33832
# [Loss Loop]  i = 32/250 | loss_hat = 0.73865, loss_1step = 0.81126, loss_2step = 0.73866
# [Loss Loop]  i = 33/250 | loss_hat = 0.79323, loss_1step = 0.74498, loss_2step = 0.79323
# [Loss Loop]  i = 34/250 | loss_hat = 0.54474, loss_1step = 0.72644, loss_2step = 0.54474
# [Loss Loop]  i = 35/250 | loss_hat = 0.46236, loss_1step = 0.31852, loss_2step = 0.46238
# [Loss Loop]  i = 36/250 | loss_hat = 0.81042, loss_1step = 0.97348, loss_2step = 0.81041
# [Loss Loop]  i = 37/250 | loss_hat = 0.54303, loss_1step = 0.62364, loss_2step = 0.54303
# [Loss Loop]  i = 38/250 | loss_hat = 0.57647, loss_1step = 0.60721, loss_2step = 0.57648
# [Loss Loop]  i = 39/250 | loss_hat = 0.74157, loss_1step = 0.71742, loss_2step = 0.74156
# [Loss Loop]  i = 40/250 | loss_hat = 0.45704, loss_1step = 1.02143, loss_2step = 0.45703
# [Loss Loop]  i = 41/250 | loss_hat = 1.06083, loss_1step = 1.08811, loss_2step = 1.06085
# [Loss Loop]  i = 42/250 | loss_hat = 0.79755, loss_1step = 1.77687, loss_2step = 0.79755
# [Loss Loop]  i = 43/250 | loss_hat = 0.36201, loss_1step = 0.20320, loss_2step = 0.36202
# [Loss Loop]  i = 44/250 | loss_hat = 0.65883, loss_1step = 0.42124, loss_2step = 0.65882
# [Loss Loop]  i = 45/250 | loss_hat = 0.69614, loss_1step = 0.91884, loss_2step = 0.69612
# [Loss Loop]  i = 46/250 | loss_hat = 0.29511, loss_1step = 0.16161, loss_2step = 0.29510
# [Loss Loop]  i = 47/250 | loss_hat = 0.55125, loss_1step = 0.48263, loss_2step = 0.55124
# [Loss Loop]  i = 48/250 | loss_hat = 0.77681, loss_1step = 0.64956, loss_2step = 0.77679
# [Loss Loop]  i = 49/250 | loss_hat = 0.69162, loss_1step = 0.54395, loss_2step = 0.69161
# [Loss Loop]  i = 50/250 | loss_hat = 0.44664, loss_1step = 0.45935, loss_2step = 0.44664
# [Loss Loop]  i = 51/250 | loss_hat = 0.36362, loss_1step = 0.35148, loss_2step = 0.36361
# [Loss Loop]  i = 52/250 | loss_hat = 0.78355, loss_1step = 0.76981, loss_2step = 0.78354
# [Loss Loop]  i = 53/250 | loss_hat = 0.41742, loss_1step = 0.32405, loss_2step = 0.41742
# [Loss Loop]  i = 54/250 | loss_hat = 0.84187, loss_1step = 1.02844, loss_2step = 0.84188
# [Loss Loop]  i = 55/250 | loss_hat = 0.46801, loss_1step = 0.57497, loss_2step = 0.46802
# [Loss Loop]  i = 56/250 | loss_hat = 0.75853, loss_1step = 0.81687, loss_2step = 0.75853
# [Loss Loop]  i = 57/250 | loss_hat = 0.54294, loss_1step = 0.49782, loss_2step = 0.54295
# [Loss Loop]  i = 58/250 | loss_hat = 0.45857, loss_1step = 0.48284, loss_2step = 0.45857
# [Loss Loop]  i = 59/250 | loss_hat = 0.53210, loss_1step = 0.44202, loss_2step = 0.53208
# [Loss Loop]  i = 60/250 | loss_hat = 0.60894, loss_1step = 0.46824, loss_2step = 0.60891
# [Loss Loop]  i = 61/250 | loss_hat = 0.78713, loss_1step = 0.39616, loss_2step = 0.78712
# [Loss Loop]  i = 62/250 | loss_hat = 0.46822, loss_1step = 0.59969, loss_2step = 0.46821
# [Loss Loop]  i = 63/250 | loss_hat = 0.53713, loss_1step = 0.67583, loss_2step = 0.53714
# [Loss Loop]  i = 64/250 | loss_hat = 0.47808, loss_1step = 0.50063, loss_2step = 0.47810
# [Loss Loop]  i = 65/250 | loss_hat = 0.36607, loss_1step = 0.86081, loss_2step = 0.36607
# [Loss Loop]  i = 66/250 | loss_hat = 0.54984, loss_1step = 0.45035, loss_2step = 0.54986
# [Loss Loop]  i = 67/250 | loss_hat = 0.45100, loss_1step = 0.35230, loss_2step = 0.45100
# [Loss Loop]  i = 68/250 | loss_hat = 1.10316, loss_1step = 1.25375, loss_2step = 1.10314
# [Loss Loop]  i = 69/250 | loss_hat = 0.84972, loss_1step = 0.83785, loss_2step = 0.84972
# [Loss Loop]  i = 70/250 | loss_hat = 0.65722, loss_1step = 0.62163, loss_2step = 0.65725
# [Loss Loop]  i = 71/250 | loss_hat = 0.79983, loss_1step = 1.00136, loss_2step = 0.79982
# [Loss Loop]  i = 72/250 | loss_hat = 0.55877, loss_1step = 0.89120, loss_2step = 0.55878
# [Loss Loop]  i = 73/250 | loss_hat = 0.73789, loss_1step = 0.85538, loss_2step = 0.73789
# [Loss Loop]  i = 74/250 | loss_hat = 1.08042, loss_1step = 0.75283, loss_2step = 1.08043
# [Loss Loop]  i = 75/250 | loss_hat = 0.74863, loss_1step = 0.39649, loss_2step = 0.74864
# [Loss Loop]  i = 76/250 | loss_hat = 0.35863, loss_1step = 0.39329, loss_2step = 0.35863
# [Loss Loop]  i = 77/250 | loss_hat = 1.10957, loss_1step = 1.19913, loss_2step = 1.10956
# [Loss Loop]  i = 78/250 | loss_hat = 0.81125, loss_1step = 1.68648, loss_2step = 0.81124
# [Loss Loop]  i = 79/250 | loss_hat = 0.90463, loss_1step = 1.12714, loss_2step = 0.90462
# [Loss Loop]  i = 80/250 | loss_hat = 0.39161, loss_1step = 0.30465, loss_2step = 0.39162
# [Loss Loop]  i = 81/250 | loss_hat = 0.53804, loss_1step = 0.69213, loss_2step = 0.53802
# [Loss Loop]  i = 82/250 | loss_hat = 0.36245, loss_1step = 0.45218, loss_2step = 0.36244
# [Loss Loop]  i = 83/250 | loss_hat = 0.34802, loss_1step = 0.17749, loss_2step = 0.34803
# [Loss Loop]  i = 84/250 | loss_hat = 0.94899, loss_1step = 0.87849, loss_2step = 0.94900
# [Loss Loop]  i = 85/250 | loss_hat = 0.65686, loss_1step = 0.49883, loss_2step = 0.65686
# [Loss Loop]  i = 86/250 | loss_hat = 0.51879, loss_1step = 0.74170, loss_2step = 0.51880
# [Loss Loop]  i = 87/250 | loss_hat = 0.73327, loss_1step = 0.88982, loss_2step = 0.73327
# [Loss Loop]  i = 88/250 | loss_hat = 0.26547, loss_1step = 0.51100, loss_2step = 0.26547
# [Loss Loop]  i = 89/250 | loss_hat = 0.64934, loss_1step = 0.38252, loss_2step = 0.64935
# [Loss Loop]  i = 90/250 | loss_hat = 0.38506, loss_1step = 0.55167, loss_2step = 0.38507
# [Loss Loop]  i = 91/250 | loss_hat = 0.55261, loss_1step = 0.55043, loss_2step = 0.55262
# [Loss Loop]  i = 92/250 | loss_hat = 0.50732, loss_1step = 0.36514, loss_2step = 0.50733
# [Loss Loop]  i = 93/250 | loss_hat = 0.58927, loss_1step = 0.51162, loss_2step = 0.58925
# [Loss Loop]  i = 94/250 | loss_hat = 0.41967, loss_1step = 0.24084, loss_2step = 0.41966
# [Loss Loop]  i = 95/250 | loss_hat = 0.39029, loss_1step = 0.33797, loss_2step = 0.39030
# [Loss Loop]  i = 96/250 | loss_hat = 0.98803, loss_1step = 0.99938, loss_2step = 0.98803
# [Loss Loop]  i = 97/250 | loss_hat = 0.57015, loss_1step = 0.48291, loss_2step = 0.57014
# [Loss Loop]  i = 98/250 | loss_hat = 0.38394, loss_1step = 0.45502, loss_2step = 0.38396
# [Loss Loop]  i = 99/250 | loss_hat = 0.69851, loss_1step = 0.49957, loss_2step = 0.69848
# [Loss Loop]  i = 100/250 | loss_hat = 0.42478, loss_1step = 0.93432, loss_2step = 0.42478
# [Loss Loop]  i = 101/250 | loss_hat = 0.71087, loss_1step = 0.56917, loss_2step = 0.71086
# [Loss Loop]  i = 102/250 | loss_hat = 0.95518, loss_1step = 0.61827, loss_2step = 0.95519
# [Loss Loop]  i = 103/250 | loss_hat = 0.69598, loss_1step = 0.36202, loss_2step = 0.69595
# [Loss Loop]  i = 104/250 | loss_hat = 0.38586, loss_1step = 0.27993, loss_2step = 0.38586
# [Loss Loop]  i = 105/250 | loss_hat = 0.65980, loss_1step = 1.03655, loss_2step = 0.65982
# [Loss Loop]  i = 106/250 | loss_hat = 1.22696, loss_1step = 0.78249, loss_2step = 1.22700
# [Loss Loop]  i = 107/250 | loss_hat = 0.70844, loss_1step = 0.77672, loss_2step = 0.70844
# [Loss Loop]  i = 108/250 | loss_hat = 1.09188, loss_1step = 1.15751, loss_2step = 1.09188
# [Loss Loop]  i = 109/250 | loss_hat = 0.43751, loss_1step = 0.31936, loss_2step = 0.43750
# [Loss Loop]  i = 110/250 | loss_hat = 0.86538, loss_1step = 1.24186, loss_2step = 0.86536
# [Loss Loop]  i = 111/250 | loss_hat = 0.62308, loss_1step = 0.73281, loss_2step = 0.62309
# [Loss Loop]  i = 112/250 | loss_hat = 0.46286, loss_1step = 0.21209, loss_2step = 0.46284
# [Loss Loop]  i = 113/250 | loss_hat = 0.29586, loss_1step = 0.63547, loss_2step = 0.29586
# [Loss Loop]  i = 114/250 | loss_hat = 0.75221, loss_1step = 1.01022, loss_2step = 0.75220
# [Loss Loop]  i = 115/250 | loss_hat = 0.55515, loss_1step = 0.32726, loss_2step = 0.55516
# [Loss Loop]  i = 116/250 | loss_hat = 0.37809, loss_1step = 0.41970, loss_2step = 0.37810
# [Loss Loop]  i = 117/250 | loss_hat = 0.35006, loss_1step = 0.13203, loss_2step = 0.35005
# [Loss Loop]  i = 118/250 | loss_hat = 0.51670, loss_1step = 0.70326, loss_2step = 0.51670
# [Loss Loop]  i = 119/250 | loss_hat = 0.57142, loss_1step = 0.54087, loss_2step = 0.57142
# [Loss Loop]  i = 120/250 | loss_hat = 0.47628, loss_1step = 0.32696, loss_2step = 0.47630
# [Loss Loop]  i = 121/250 | loss_hat = 0.69811, loss_1step = 0.72987, loss_2step = 0.69809
# [Loss Loop]  i = 122/250 | loss_hat = 0.42769, loss_1step = 0.57588, loss_2step = 0.42768
# [Loss Loop]  i = 123/250 | loss_hat = 0.49653, loss_1step = 0.79900, loss_2step = 0.49653
# [Loss Loop]  i = 124/250 | loss_hat = 0.70239, loss_1step = 0.43352, loss_2step = 0.70240
# [Loss Loop]  i = 125/250 | loss_hat = 0.75880, loss_1step = 0.79918, loss_2step = 0.75879
# [Loss Loop]  i = 126/250 | loss_hat = 0.73045, loss_1step = 0.93057, loss_2step = 0.73046
# [Loss Loop]  i = 127/250 | loss_hat = 0.51226, loss_1step = 0.49648, loss_2step = 0.51227
# [Loss Loop]  i = 128/250 | loss_hat = 0.69289, loss_1step = 0.57831, loss_2step = 0.69291
# [Loss Loop]  i = 129/250 | loss_hat = 0.72073, loss_1step = 0.64199, loss_2step = 0.72073
# [Loss Loop]  i = 130/250 | loss_hat = 0.49915, loss_1step = 0.70330, loss_2step = 0.49915
# [Loss Loop]  i = 131/250 | loss_hat = 0.25012, loss_1step = 0.34431, loss_2step = 0.25012
# [Loss Loop]  i = 132/250 | loss_hat = 0.46837, loss_1step = 0.83779, loss_2step = 0.46838
# [Loss Loop]  i = 133/250 | loss_hat = 0.43144, loss_1step = 0.17102, loss_2step = 0.43144
# [Loss Loop]  i = 134/250 | loss_hat = 0.61861, loss_1step = 0.52519, loss_2step = 0.61861
# [Loss Loop]  i = 135/250 | loss_hat = 0.37808, loss_1step = 0.53654, loss_2step = 0.37810
# [Loss Loop]  i = 136/250 | loss_hat = 0.29177, loss_1step = 0.20420, loss_2step = 0.29177
# [Loss Loop]  i = 137/250 | loss_hat = 0.62733, loss_1step = 0.53694, loss_2step = 0.62734
# [Loss Loop]  i = 138/250 | loss_hat = 0.79898, loss_1step = 0.61366, loss_2step = 0.79899
# [Loss Loop]  i = 139/250 | loss_hat = 0.38057, loss_1step = 0.54709, loss_2step = 0.38057
# [Loss Loop]  i = 140/250 | loss_hat = 0.96781, loss_1step = 0.70106, loss_2step = 0.96781
# [Loss Loop]  i = 141/250 | loss_hat = 0.37078, loss_1step = 0.43370, loss_2step = 0.37077
# [Loss Loop]  i = 142/250 | loss_hat = 0.61670, loss_1step = 0.54479, loss_2step = 0.61671
# [Loss Loop]  i = 143/250 | loss_hat = 0.60643, loss_1step = 0.45678, loss_2step = 0.60643
# [Loss Loop]  i = 144/250 | loss_hat = 0.56718, loss_1step = 0.27842, loss_2step = 0.56715
# [Loss Loop]  i = 145/250 | loss_hat = 0.96713, loss_1step = 1.36669, loss_2step = 0.96716
# [Loss Loop]  i = 146/250 | loss_hat = 0.21007, loss_1step = 0.12973, loss_2step = 0.21008
# [Loss Loop]  i = 147/250 | loss_hat = 0.49644, loss_1step = 0.66505, loss_2step = 0.49645
# [Loss Loop]  i = 148/250 | loss_hat = 0.56853, loss_1step = 0.84859, loss_2step = 0.56855
# [Loss Loop]  i = 149/250 | loss_hat = 0.61740, loss_1step = 0.69791, loss_2step = 0.61739
# [Loss Loop]  i = 150/250 | loss_hat = 0.69777, loss_1step = 1.06886, loss_2step = 0.69778
# [Loss Loop]  i = 151/250 | loss_hat = 0.95764, loss_1step = 1.33526, loss_2step = 0.95764
# [Loss Loop]  i = 152/250 | loss_hat = 0.54352, loss_1step = 0.29483, loss_2step = 0.54351
# [Loss Loop]  i = 153/250 | loss_hat = 0.55411, loss_1step = 0.45374, loss_2step = 0.55412
# [Loss Loop]  i = 154/250 | loss_hat = 0.81245, loss_1step = 0.50523, loss_2step = 0.81244
# [Loss Loop]  i = 155/250 | loss_hat = 0.71589, loss_1step = 0.53950, loss_2step = 0.71591
# [Loss Loop]  i = 156/250 | loss_hat = 0.43725, loss_1step = 0.25435, loss_2step = 0.43725
# [Loss Loop]  i = 157/250 | loss_hat = 0.20077, loss_1step = 0.18247, loss_2step = 0.20077
# [Loss Loop]  i = 158/250 | loss_hat = 0.68970, loss_1step = 0.73222, loss_2step = 0.68970
# [Loss Loop]  i = 159/250 | loss_hat = 0.45781, loss_1step = 0.29789, loss_2step = 0.45781
# [Loss Loop]  i = 160/250 | loss_hat = 0.72808, loss_1step = 0.74262, loss_2step = 0.72809
# [Loss Loop]  i = 161/250 | loss_hat = 0.68705, loss_1step = 0.69699, loss_2step = 0.68705
# [Loss Loop]  i = 162/250 | loss_hat = 0.97346, loss_1step = 1.35901, loss_2step = 0.97345
# [Loss Loop]  i = 163/250 | loss_hat = 1.28451, loss_1step = 1.42379, loss_2step = 1.28451
# [Loss Loop]  i = 164/250 | loss_hat = 1.16894, loss_1step = 1.12619, loss_2step = 1.16892
# [Loss Loop]  i = 165/250 | loss_hat = 0.67774, loss_1step = 0.55993, loss_2step = 0.67772
# [Loss Loop]  i = 166/250 | loss_hat = 0.75779, loss_1step = 0.74464, loss_2step = 0.75778
# [Loss Loop]  i = 167/250 | loss_hat = 0.52504, loss_1step = 0.54980, loss_2step = 0.52505
# [Loss Loop]  i = 168/250 | loss_hat = 0.50850, loss_1step = 0.78190, loss_2step = 0.50851
# [Loss Loop]  i = 169/250 | loss_hat = 0.58587, loss_1step = 0.59570, loss_2step = 0.58586
# [Loss Loop]  i = 170/250 | loss_hat = 0.76346, loss_1step = 1.15202, loss_2step = 0.76345
# [Loss Loop]  i = 171/250 | loss_hat = 0.67412, loss_1step = 0.85439, loss_2step = 0.67412
# [Loss Loop]  i = 172/250 | loss_hat = 0.43834, loss_1step = 0.34223, loss_2step = 0.43834
# [Loss Loop]  i = 173/250 | loss_hat = 0.43707, loss_1step = 0.41776, loss_2step = 0.43708
# [Loss Loop]  i = 174/250 | loss_hat = 0.77374, loss_1step = 1.09079, loss_2step = 0.77374
# [Loss Loop]  i = 175/250 | loss_hat = 0.69524, loss_1step = 1.20416, loss_2step = 0.69521
# [Loss Loop]  i = 176/250 | loss_hat = 0.62236, loss_1step = 0.49590, loss_2step = 0.62236
# [Loss Loop]  i = 177/250 | loss_hat = 1.03664, loss_1step = 1.48371, loss_2step = 1.03668
# [Loss Loop]  i = 178/250 | loss_hat = 0.67153, loss_1step = 0.69282, loss_2step = 0.67151
# [Loss Loop]  i = 179/250 | loss_hat = 0.46500, loss_1step = 0.27353, loss_2step = 0.46500
# [Loss Loop]  i = 180/250 | loss_hat = 0.47205, loss_1step = 0.57856, loss_2step = 0.47204
# [Loss Loop]  i = 181/250 | loss_hat = 0.59061, loss_1step = 0.72583, loss_2step = 0.59061
# [Loss Loop]  i = 182/250 | loss_hat = 0.28483, loss_1step = 0.39532, loss_2step = 0.28483
# [Loss Loop]  i = 183/250 | loss_hat = 1.02222, loss_1step = 1.61280, loss_2step = 1.02220
# [Loss Loop]  i = 184/250 | loss_hat = 0.62534, loss_1step = 0.35900, loss_2step = 0.62533
# [Loss Loop]  i = 185/250 | loss_hat = 0.28136, loss_1step = 0.40884, loss_2step = 0.28136
# [Loss Loop]  i = 186/250 | loss_hat = 0.68179, loss_1step = 0.69421, loss_2step = 0.68178
# [Loss Loop]  i = 187/250 | loss_hat = 0.84763, loss_1step = 0.70111, loss_2step = 0.84763
# [Loss Loop]  i = 188/250 | loss_hat = 0.55053, loss_1step = 0.70447, loss_2step = 0.55054
# [Loss Loop]  i = 189/250 | loss_hat = 0.42002, loss_1step = 0.30906, loss_2step = 0.42002
# [Loss Loop]  i = 190/250 | loss_hat = 0.49674, loss_1step = 0.32518, loss_2step = 0.49673
# [Loss Loop]  i = 191/250 | loss_hat = 0.66019, loss_1step = 0.57604, loss_2step = 0.66018
# [Loss Loop]  i = 192/250 | loss_hat = 0.75282, loss_1step = 0.83814, loss_2step = 0.75282
# [Loss Loop]  i = 193/250 | loss_hat = 0.54517, loss_1step = 0.38275, loss_2step = 0.54516
# [Loss Loop]  i = 194/250 | loss_hat = 0.56083, loss_1step = 1.04290, loss_2step = 0.56083
# [Loss Loop]  i = 195/250 | loss_hat = 0.55380, loss_1step = 0.73154, loss_2step = 0.55380
# [Loss Loop]  i = 196/250 | loss_hat = 0.41754, loss_1step = 0.37580, loss_2step = 0.41755
# [Loss Loop]  i = 197/250 | loss_hat = 1.04929, loss_1step = 0.96884, loss_2step = 1.04928
# [Loss Loop]  i = 198/250 | loss_hat = 1.07191, loss_1step = 0.88233, loss_2step = 1.07191
# [Loss Loop]  i = 199/250 | loss_hat = 0.64352, loss_1step = 0.96068, loss_2step = 0.64355
# [Loss Loop]  i = 200/250 | loss_hat = 0.85851, loss_1step = 0.91365, loss_2step = 0.85851
# [Loss Loop]  i = 201/250 | loss_hat = 0.86935, loss_1step = 0.78064, loss_2step = 0.86937
# [Loss Loop]  i = 202/250 | loss_hat = 0.38396, loss_1step = 0.24916, loss_2step = 0.38397
# [Loss Loop]  i = 203/250 | loss_hat = 0.55312, loss_1step = 0.48296, loss_2step = 0.55313
# [Loss Loop]  i = 204/250 | loss_hat = 0.24906, loss_1step = 0.16093, loss_2step = 0.24906
# [Loss Loop]  i = 205/250 | loss_hat = 0.57876, loss_1step = 0.25313, loss_2step = 0.57876
# [Loss Loop]  i = 206/250 | loss_hat = 1.13670, loss_1step = 1.23896, loss_2step = 1.13668
# [Loss Loop]  i = 207/250 | loss_hat = 0.46707, loss_1step = 0.42582, loss_2step = 0.46706
# [Loss Loop]  i = 208/250 | loss_hat = 0.64223, loss_1step = 0.53988, loss_2step = 0.64224
# [Loss Loop]  i = 209/250 | loss_hat = 0.55515, loss_1step = 0.48809, loss_2step = 0.55516
# [Loss Loop]  i = 210/250 | loss_hat = 0.81091, loss_1step = 0.67401, loss_2step = 0.81089
# [Loss Loop]  i = 211/250 | loss_hat = 0.83518, loss_1step = 0.92410, loss_2step = 0.83517
# [Loss Loop]  i = 212/250 | loss_hat = 0.62780, loss_1step = 0.47868, loss_2step = 0.62781
# [Loss Loop]  i = 213/250 | loss_hat = 0.37031, loss_1step = 0.52388, loss_2step = 0.37030
# [Loss Loop]  i = 214/250 | loss_hat = 0.65377, loss_1step = 0.43352, loss_2step = 0.65377
# [Loss Loop]  i = 215/250 | loss_hat = 0.40524, loss_1step = 0.31331, loss_2step = 0.40523
# [Loss Loop]  i = 216/250 | loss_hat = 0.69060, loss_1step = 0.66979, loss_2step = 0.69059
# [Loss Loop]  i = 217/250 | loss_hat = 0.63275, loss_1step = 0.78433, loss_2step = 0.63276
# [Loss Loop]  i = 218/250 | loss_hat = 0.17495, loss_1step = 0.19933, loss_2step = 0.17494
# [Loss Loop]  i = 219/250 | loss_hat = 0.81962, loss_1step = 0.74624, loss_2step = 0.81964
# [Loss Loop]  i = 220/250 | loss_hat = 0.89173, loss_1step = 1.00096, loss_2step = 0.89173
# [Loss Loop]  i = 221/250 | loss_hat = 0.68386, loss_1step = 0.60746, loss_2step = 0.68386
# [Loss Loop]  i = 222/250 | loss_hat = 0.44977, loss_1step = 0.37325, loss_2step = 0.44978
# [Loss Loop]  i = 223/250 | loss_hat = 0.75208, loss_1step = 0.52474, loss_2step = 0.75208
# [Loss Loop]  i = 224/250 | loss_hat = 0.57310, loss_1step = 1.10708, loss_2step = 0.57311
# [Loss Loop]  i = 225/250 | loss_hat = 0.65710, loss_1step = 0.87545, loss_2step = 0.65711
# [Loss Loop]  i = 226/250 | loss_hat = 0.44117, loss_1step = 0.35293, loss_2step = 0.44118
# [Loss Loop]  i = 227/250 | loss_hat = 0.49526, loss_1step = 0.32848, loss_2step = 0.49527
# [Loss Loop]  i = 228/250 | loss_hat = 0.56305, loss_1step = 0.34497, loss_2step = 0.56304
# [Loss Loop]  i = 229/250 | loss_hat = 0.49862, loss_1step = 0.49342, loss_2step = 0.49863
# [Loss Loop]  i = 230/250 | loss_hat = 0.46401, loss_1step = 0.50757, loss_2step = 0.46400
# [Loss Loop]  i = 231/250 | loss_hat = 0.70720, loss_1step = 0.44561, loss_2step = 0.70720
# [Loss Loop]  i = 232/250 | loss_hat = 0.31569, loss_1step = 0.50156, loss_2step = 0.31569
# [Loss Loop]  i = 233/250 | loss_hat = 0.74142, loss_1step = 0.60089, loss_2step = 0.74142
# [Loss Loop]  i = 234/250 | loss_hat = 0.70478, loss_1step = 0.49568, loss_2step = 0.70482
# [Loss Loop]  i = 235/250 | loss_hat = 0.72097, loss_1step = 0.58911, loss_2step = 0.72094
# [Loss Loop]  i = 236/250 | loss_hat = 0.55807, loss_1step = 0.56193, loss_2step = 0.55806
# [Loss Loop]  i = 237/250 | loss_hat = 0.80160, loss_1step = 0.35850, loss_2step = 0.80162
# [Loss Loop]  i = 238/250 | loss_hat = 1.00759, loss_1step = 0.98152, loss_2step = 1.00761
# [Loss Loop]  i = 239/250 | loss_hat = 0.76183, loss_1step = 0.74739, loss_2step = 0.76184
# [Loss Loop]  i = 240/250 | loss_hat = 0.57395, loss_1step = 0.70947, loss_2step = 0.57394
# [Loss Loop]  i = 241/250 | loss_hat = 0.40833, loss_1step = 0.51867, loss_2step = 0.40832
# [Loss Loop]  i = 242/250 | loss_hat = 0.58955, loss_1step = 0.72809, loss_2step = 0.58953
# [Loss Loop]  i = 243/250 | loss_hat = 0.37958, loss_1step = 0.36924, loss_2step = 0.37958
# [Loss Loop]  i = 244/250 | loss_hat = 0.41226, loss_1step = 0.31805, loss_2step = 0.41224
# [Loss Loop]  i = 245/250 | loss_hat = 0.96895, loss_1step = 1.16070, loss_2step = 0.96895
# [Loss Loop]  i = 246/250 | loss_hat = 0.48042, loss_1step = 0.43143, loss_2step = 0.48043
# [Loss Loop]  i = 247/250 | loss_hat = 0.71337, loss_1step = 0.48157, loss_2step = 0.71337
# [Loss Loop]  i = 248/250 | loss_hat = 0.89177, loss_1step = 1.09769, loss_2step = 0.89173
# [Loss Loop]  i = 249/250 | loss_hat = 0.66566, loss_1step = 0.60196, loss_2step = 0.66568
# [Loss Loop]  i = 250/250 | loss_hat = 0.77372, loss_1step = 0.98767, loss_2step = 0.77374
#
# --- Summary for p = 500, n = 250, df/p = 0.13 ---
# Error (Exact LOO) | Min: 0.16352, Q1: 0.33886, Median: 0.40204, Q3: 0.45916, Max: 0.66582
# Error (1-Step) | Min: 0.00008, Q1: 0.00025, Median: 0.00036, Q3: 0.00047, Max: 0.00131
# Error (2-Step) | Min: 0.00000, Q1: 0.00000, Median: 0.00000, Q3: 0.00000, Max: 0.00000
# Loss (Exact) | Min: 0.17495, Q1: 0.46731, Median: 0.61282, Q3: 0.75122, Max: 1.37385
# Loss (1-Step) | Min: 0.12973, Q1: 0.42008, Median: 0.56555, Q3: 0.79913, Max: 1.77687
# Loss (2-Step) | Min: 0.17494, Q1: 0.46730, Median: 0.61281, Q3: 0.75122, Max: 1.37386

# %%
r1 = np.zeros(n)
r2 = np.zeros(n)

for i in range(1, n):
    r1[i] = np.max(errors_tilde[:i]) * np.sqrt(np.log(n) / np.log(i + 1))
    r2[i] = np.max(errors_tilde_2[:i]) * np.sqrt(np.log(n) / np.log(i + 1))

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

x = np.arange(len(r1))
print(f"Length of r1: {len(r1)}")
print(f"Length of r2: {len(r2)}")
print(f"Value of n  : {n}")


# --- Plot for 1-step ---
axes[0].plot(x, r1, '--', label=r"$r_1(i)$ Upper Bound", linewidth=2)
axes[0].set_xlabel("i")
axes[0].set_ylabel("Error")
axes[0].set_title("1-Step Error vs Upper Bound")
axes[0].legend()
axes[0].grid(True)

# --- Plot for 2-step ---
axes[1].plot(x, r2, '--', label=r"$r_2(i)$ Upper Bound", linewidth=2, color='red')
axes[1].set_xlabel("i")
axes[1].set_ylabel("Error")
axes[1].set_title("2-Step Error vs Upper Bound")
axes[1].legend()
axes[1].grid(True)

# Title with parameters
fig.suptitle(rf'$n/p = {n/p:.1f},\ df/p = {tr_H:.2f},\ \lambda = {lambda_}$', fontsize=16, y=1.05)

plt.tight_layout()
plt.show()
# Out:
# Length of r1: 250
# Length of r2: 250
# Value of n  : 250

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- Create test data ---
n_test = 1000
X_test = np.random.normal(0, 1 / np.sqrt(n), (n_test, p))
logits_test = X_test @ beta_star
y_test = np.random.binomial(1, sigmoid(logits_test))

# --- Metrics ---
def log_loss(y_true, X_data, beta):
    logits = X_data @ beta
    pred = sigmoid(logits)
    pred = np.clip(pred, 1e-10, 1 - 1e-10)  # avoid log(0)
    return -np.mean(y_true * np.log(pred) + (1 - y_true) * np.log(1 - pred))

def error_rate(y_true, X_data, beta):
    prob = sigmoid(X_data @ beta)
    y_pred = (prob >= 0.5).astype(int)
    return np.mean(y_pred != y_true)

# --- Compute Train/Test Loss ---
train_loss_star = log_loss(y, X, beta_star)
train_loss_hat  = log_loss(y, X, beta_hat)
test_loss_star  = log_loss(y_test, X_test, beta_star)
test_loss_hat   = log_loss(y_test, X_test, beta_hat)

# --- Compute Train/Test Error Rate ---
train_error_star = error_rate(y, X, beta_star)
train_error_hat  = error_rate(y, X, beta_hat)
test_error_star  = error_rate(y_test, X_test, beta_star)
test_error_hat   = error_rate(y_test, X_test, beta_hat)

# --- Print All Results ---
print("--- Training and Test Losses ---")
print(f"Train Loss (beta_star): {train_loss_star:.5f}")
print(f"Train Loss (beta_hat) : {train_loss_hat:.5f}")
print(f"Test  Loss (beta_star): {test_loss_star:.5f}")
print(f"Test  Loss (beta_hat) : {test_loss_hat:.5f}")

print("\n--- Classification Error Rates ---")
print(f"Train Error (beta_star): {train_error_star:.4f}")
print(f"Train Error (beta_hat) : {train_error_hat:.4f}")
print(f"Test  Error (beta_star): {test_error_star:.4f}")
print(f"Test  Error (beta_hat) : {test_error_hat:.4f}")

# --- Scatter Plots: Approx vs Exact LOO Loss ---
plt.figure(figsize=(12, 5))

# 1-Step
plt.subplot(1, 2, 1)
plt.scatter(loss_hat, loss_tilde, alpha=0.6, label="(1-Step + Noise) Approximation")
plt.plot(loss_hat, loss_hat, 'k--', label="y = x")
plt.xlabel("Exact Leave-One-Out Loss")
plt.ylabel("(1-Step + Noise) Loss")
plt.title("Exact vs (1-Step + Noise) Loss")
plt.legend()
plt.grid(True)

# 2-Step
plt.subplot(1, 2, 2)
plt.scatter(loss_hat, loss_tilde_2, alpha=0.6, color='orange', label="(2-Step + Noise) Approximation")
plt.plot(loss_hat, loss_hat, 'k--', label="y = x")
plt.xlabel("Exact Leave-One-Out Loss")
plt.ylabel("(2-Step + Noise) Loss")
plt.title("Exact vs (2-Step + Noise) Loss")
plt.legend()
plt.grid(True)

# Title
plt.suptitle(rf'$n = {n},\ p = {p},\ df/p = {tr_H:.2f},\ \lambda = {lambda_}$', fontsize=16, y=1.05)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()
# Out:
# --- Training and Test Losses ---
# Train Loss (beta_star): 0.31818
# Train Loss (beta_hat) : 0.39791
# Test  Loss (beta_star): 0.36544
# Test  Loss (beta_hat) : 0.65131
#
# --- Classification Error Rates ---
# Train Error (beta_star): 0.1320
# Train Error (beta_hat) : 0.0080
# Test  Error (beta_star): 0.1640
# Test  Error (beta_hat) : 0.3820
